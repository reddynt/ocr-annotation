# %%
import pymongo

# %%
client = pymongo.MongoClient("localhost", 27017)
db = client["ocr_annotation"]
collection = db.entity
collection = db.annotations
print(len(list(collection.find({}, {"_id": False}))))
# Out:
# 17

# %%
list(collection.find({"imageName": "invoice.png"}))
# Out:
# [{'_id': ObjectId('64310c73e2c59872d36970ae'),
#   'imageName': 'invoice.png',
#   'entities': [{'level': 5,
#     'page_num': 1,
#     'block_num': 1,
#     'par_num': 1,
#     'line_num': 1,
#     'word_num': 1,
#     'left': 48,
#     'top': 36,
#     'width': 147,
#     'height': 41,
#     'conf': 96.711548,
#     'text': 'INVOICE',
#     'entity': None,
#     'colour': '#d3d3d3'},
#    {'level': 5,
#     'page_num': 1,
#     'block_num': 2,
#     'par_num': 1,
#     'line_num': 1,
#     'word_num': 1,
#     'left': 47,
#     'top': 98,
#     'width': 22,
#     'height': 8,
#     'conf': 78.140144,
#     'text': 'East',
#     'entity': None,
#     'colour': '#d3d3d3'},
#    {'level': 5,
#     'page_num': 1,
#     'block_num': 2,
#     'par_num': 1,
#     'line_num': 1,
#     'word_num': 2,
#     'left': 72,
#     'top': 98,
#     'width': 34,
#     'height': 9,
#     'conf': 83.566429,
#     'text': 'Repair',
#     'entity': None,
#     'colour': '#d3d3d3'},
#    {'level': 5,
# ...

# %%
collection.insert_one({"name": "sample", "color": "teal"})
